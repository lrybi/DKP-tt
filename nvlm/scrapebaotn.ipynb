# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

response = requests.get('https://thanhnien.vn/the-gioi.htm', headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html lang="vi">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Tin thế giới - Tin tức, thời sự quốc tế, an ninh, quân sự
#   </title>
#   <meta content="Tin thế giới - Tin tức an ninh, quân sự thế giới 24h trong ngày. Thời sự quốc tế, tin nhanh thế giới mới nhất. Giá vàng, giá dầu, giá đường thế giới" name="description"/>
#   <meta content="Tin thế giới - Tin tức an ninh, quân sự thế giới 24h trong ngày. Thời sự quốc tế, tin nhanh thế giới mới nhất. Giá vàng, giá dầu, giá đường thế giới" name="keywords"/>
#   <meta content="Tin thế giới - Tin tức an ninh, quân sự thế giới 24h trong ngày. Thời sự quốc tế, tin nhanh thế giới mới nhất. Giá vàng, giá dầu, giá đường thế giới" name="news_keywords"/>
#   <meta content="Tin thế giới - Tin tức, thời sự quốc tế, an ninh, quân sự" property="og:title"/>
# ...

# %%
raw_main_list = soup.find('div', {'class':'box-category-middle list__main_check'})
print(raw_main_list.prettify()[:5000])
# Out:
# <div class="box-category-middle list__main_check">
#  <div class="box-category-item" data-id="185250317105328908" data-newstype="0" data-rolling-news-id="0" data-type="0">
#   <a class="box-category-link-with-avatar img-resize" data-io-canonical-url="/nghi-si-phap-doi-my-tra-lai-tuong-nu-than-tu-do-185250317105328908.htm" href="/nghi-si-phap-doi-my-tra-lai-tuong-nu-than-tu-do-185250317105328908.htm" title="Nghị sĩ Pháp đòi Mỹ trả lại tượng Nữ thần Tự do">
# ...

# %%
raw_main_list.find('div', {'class':'box-category-item'})
# Out:
# <div class="box-category-item" data-id="185250317105328908" data-newstype="0" data-rolling-news-id="0" data-type="0">
# <a class="box-category-link-with-avatar img-resize" data-io-canonical-url="/nghi-si-phap-doi-my-tra-lai-tuong-nu-than-tu-do-185250317105328908.htm" href="/nghi-si-phap-doi-my-tra-lai-tuong-nu-than-tu-do-185250317105328908.htm" title="Nghị sĩ Pháp đòi Mỹ trả lại tượng Nữ thần Tự do">
# ...

# %%
soup.find('div', {'class':'box-category-item'})
# Out:
# <div class="box-category-item" data-id="185250317150837623" data-vr-contentbox="Cate - Nổi bật 2" data-vr-contentbox-url="https://thanhnien.vn/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm">
# <a class="box-category-link-with-avatar img-resize" data-io-canonical-url="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" href="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" title="Triều Tiên dọa tăng cường lực lượng hạt nhân cả chất lẫn lượng">
# ...

# %%
(soup.find_all('div', {'class':'box-category-item'})[0]).find('a', 'box-category-link-with-avatar img-resize')
# Out:
# <a class="box-category-link-with-avatar img-resize" data-io-canonical-url="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" href="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" title="Triều Tiên dọa tăng cường lực lượng hạt nhân cả chất lẫn lượng">
# <img alt="Triều Tiên dọa tăng cường lực lượng hạt nhân cả chất lẫn lượng" class="box-category-avatar" data-type="avatar" src="https://images2.thanhnien.vn/zoom/253_158/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg" srcset="https://images2.thanhnien.vn/zoom/253_158/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg 1x,https://images2.thanhnien.vn/zoom/506_316/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg 2x"/>
# </a>

# %%
(soup.find_all('div', {'class':'box-category-item'})[0]).find('a', 'box-category-link-with-avatar img-resize')
# Out:
# <a class="box-category-link-with-avatar img-resize" data-io-canonical-url="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" href="/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm" title="Triều Tiên dọa tăng cường lực lượng hạt nhân cả chất lẫn lượng">
# <img alt="Triều Tiên dọa tăng cường lực lượng hạt nhân cả chất lẫn lượng" class="box-category-avatar" data-type="avatar" src="https://images2.thanhnien.vn/zoom/253_158/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg" srcset="https://images2.thanhnien.vn/zoom/253_158/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg 1x,https://images2.thanhnien.vn/zoom/506_316/528068263637045248/2025/3/17/djegblwytrl6hiqc4lbubc3sl4-1742198639548959239829-18-114-1147-1920-crop-17421987253411417793166.jpg 2x"/>
# </a>

# %%
(soup.find_all('div', {'class':'box-category-item'})[0]).find('a', 'box-category-link-with-avatar img-resize')['href']
# Out:
# '/trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm'

# %%
'https://thanhnien.vn/' + (soup.find_all('div', {'class':'box-category-item'})[0]).find('a', 'box-category-link-with-avatar img-resize')['href']
# Out:
# 'https://thanhnien.vn//trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm'

# %%
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

response = requests.get('https://thanhnien.vn/the-gioi.htm', headers=headers) 

soup = BeautifulSoup(response.text, 'html.parser')

raw_listing_news = soup.find_all('div', {'class':'box-category-item'})

for raw_Item_news in raw_listing_news[:5]:
    href_article = raw_Item_news.find('a', 'box-category-link-with-avatar img-resize')['href']
    print('https://thanhnien.vn/' + href_article)
# Out:
# https://thanhnien.vn//ong-trump-huy-lenh-an-xa-cua-ong-biden-doa-dieu-tra-nhieu-nguoi-185250317161812583.htm
# https://thanhnien.vn//trieu-tien-doa-tang-cuong-luc-luong-hat-nhan-ca-chat-lan-luong-185250317150837623.htm
# https://thanhnien.vn//benh-vien-han-quoc-khong-tiep-nhan-thai-phu-nguoi-viet-sinh-con-tren-xe-cuu-thuong-185250317144713686.htm
# https://thanhnien.vn//ong-trump-chot-lich-ban-chuyen-ukraine-voi-ong-putin-vao-ngay-mai-185250317145513486.htm
# https://thanhnien.vn//the-gioi-moi-tu-su-tro-lai-cua-ong-trump-185250315111039033.htm

# %%
response = requests.get('https://thanhnien.vn/the-gioi.htm', headers=headers) 

soup = BeautifulSoup(response.text, 'html.parser')

raw_listing_news = soup.find_all('div', {'class':'box-category-item'})

for raw_Item_news in raw_listing_news[:5]:
    href_article = 'https://thanhnien.vn/' + raw_Item_news.find('a', 'box-category-link-with-avatar img-resize')['href']
    print(href_article)
    response = requests.get(href_article, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    print(soup.prettify()[:5000])
    
    break
# Out:
# https://thanhnien.vn//thuong-vien-philippines-dieu-tra-vu-bat-cuu-tong-thong-rodrigo-duterte-18525031718080899.htm
# <!DOCTYPE html>
# <html lang="vi">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Thượng viện Philippines điều tra vụ bắt cựu Tổng thống Rodrigo Duterte
#   </title>
#   <meta content="Thượng viện Philippines sẽ điều tra vụ bắt giữ và giao cựu Tổng thống Rodrigo Duterte cho Tòa án Hình sự quốc tế (ICC) mới đây." name="description"/>
#   <meta content="Rodrigo Duterte, Cựu tổng thống Philippines, ICC, thượng viện philippines" name="keywords"/>
#   <meta content="Rodrigo Duterte, Cựu tổng thống Philippines, ICC, thượng viện philippines" name="news_keywords"/>
#   <meta content="Thượng viện Philippines điều tra vụ bắt cựu Tổng thống Rodrigo Duterte" property="og:title"/>
# ...

# %%
masterlisst = []
l = []
for i in l:
    print(i)
    masterlisst.append(i)

print(masterlisst)
print(len(masterlisst))
# Out:
# []
# 0

# %%
ARTICLE = []
ARTICLE_IMAGE = []
IMAGE = []
image_ids = set()  # tạo tập hợp để lưu các ImageID đã có (cách này chắc nhanh hơn)
ARTICLE_VIDEO = []
VIDEO = []
video_ids = set()  # tạo tập hợp để lưu các VideoID đã có (cách này chắc nhanh hơn)


headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

response = requests.get('https://thanhnien.vn/the-gioi.htm', headers=headers) 

soup = BeautifulSoup(response.text, 'html.parser')

raw_listing_news = soup.find_all('div', {'class':'box-category-item'})

for raw_Item_news in raw_listing_news[:3]:
    ARTICLE_dict = {}
    #ARTICLE_IMAGE_dict = {}
    #IMAGE_dict = {}
    #ARTICLE_VIDEO_dict = {}
    #VIDEO_dict = {}
    
    href_article = 'https://thanhnien.vn/' + raw_Item_news.find('a', {'class':'box-category-link-with-avatar img-resize'})['href']
    print(href_article)
    response = requests.get(href_article, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    ARTICLE_dict['ArticleID'] = href_article[-27:].replace('.htm', '')
    ARTICLE_dict['Title'] = soup.title.text
    ARTICLE_dict['Url'] = href_article
    ARTICLE_dict['Category'] = soup.find('a', {'class':'category-page__name'}).text
    ARTICLE_dict['Date'] = soup.find('div', {'class':'detail-time'}).text.strip()[:-6]
    ARTICLE_dict['Writer'] = soup.find('div', {'class':'author-info-top'}).text.strip().replace('\n',' ').replace('  ',' ')
                    #ARTICLE_dict['Audio'] = soup.find('div', {'class':'detail-cmain'})
                    #print(soup.find('div', {'class':'detail-content afcbc-body'}).text.strip())
                    #print((soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']))
    content = soup.find('h2', {'class':'detail-sapo'}).text.strip() + "\n"
    for i in (soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']):
        content += i.text.strip() + "\n"
                    #print(content)
    ARTICLE_dict['Content'] = content

    main_frame = soup.find('div', {'class':'detail-cmain'})
                    # print(main_frame.find_all('img'))
                    # print(main_frame.find('img')['data-original'])
                    # print(len(main_frame.find_all('img')))
                    # a=0
                    # for i in (main_frame.find_all('img')):
                    #     #if 'data-original' in i.attrs:
                    #     if i.get('data-original'):
                    #         a+=1
                    # print(a)
    
    for i in (main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})):
        IMAGE_dict = {}
        ARTICLE_IMAGE_dict = {}
        IMAGE_dict["ImageID"] = i.find('img').get('data-original').strip()[-34:].replace('.jpg','')
        IMAGE_dict["ImageUrl"] = i.find('img').get('data-original').strip()
        IMAGE_dict["Decription"] = i.find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip()
        IMAGE_dict["Source"] = i.find('div', {'class':'PhotoCMS_Author'}).text.strip()
                    # print(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'}))
                    # print(len(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})))
                    # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('img').get('data-original'))
                    # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip())
                    # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('div', {'class':'PhotoCMS_Author'}).text.strip())
        #print(IMAGE_dict)
        # if not IMAGE or not any(d["ImageID"] == IMAGE_dict["ImageID"] for d in IMAGE):
            # IMAGE.append(IMAGE_dict)
        if IMAGE_dict["ImageID"] not in image_ids:
            IMAGE.append(IMAGE_dict)
            image_ids.add(IMAGE_dict["ImageID"])
        ARTICLE_IMAGE_dict["ArticleID"] = ARTICLE_dict['ArticleID']
        ARTICLE_IMAGE_dict["ImageID"] = IMAGE_dict["ImageID"]
        ARTICLE_IMAGE.append(ARTICLE_IMAGE_dict)

                    # print(len(main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                    # print((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                    # print('https://'+((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'}))[0]['data-vid']).strip())
    for i in (main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})):
        VIDEO_dict = {}
        ARTICLE_VIDEO_dict = {}
        VIDEO_dict["VideoID"] = i['data-vid'].strip()[-34:].replace('.mp4','')
        VIDEO_dict["VideoUrl"] = 'https://'+ i['data-vid'].strip()
        VIDEO_dict["Decription"] = i.find('div', {'class':'VideoCMS_Caption'}).text.strip()
        if VIDEO_dict["VideoID"] not in video_ids:
            VIDEO.append(VIDEO_dict)
            video_ids.add(VIDEO_dict["VideoID"])
        ARTICLE_VIDEO_dict["ArticleID"] = ARTICLE_dict['ArticleID']
        ARTICLE_VIDEO_dict["VideoID"] = VIDEO_dict["VideoID"]
        ARTICLE_VIDEO.append(ARTICLE_VIDEO_dict)

    
    ARTICLE.append(ARTICLE_dict)
    #IMAGE.append(IMAGE_dict)
    
    print(ARTICLE)
    print(IMAGE)
    print(ARTICLE_IMAGE)
    print(VIDEO)
    print(ARTICLE_VIDEO)
    
    #break
# Out:
# https://thanhnien.vn//tong-thong-trump-khong-cho-mat-vu-tiep-tuc-bao-ve-hai-nguoi-con-cua-ong-biden-18525031808505304.htm
# ...

# %%
df = pd.DataFrame(ARTICLE)
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M')
df
# Out:
#                  ArticleID                                              Title  \
# 0  biden-18525031808505304  Tổng thống Trump không cho Mật vụ tiếp tục bảo...
# 1  nedy-185250318081459953  Mỹ sắp công bố 80.000 trang tài liệu về vụ ám ...
# 2  dich-185250318080545601  Israel bất ngờ tấn công khắp Gaza, tuyên bố đẩ...
#
#                                                  Url  Category  \
# 0  https://thanhnien.vn//tong-thong-trump-khong-c...  Thế giới
# 1  https://thanhnien.vn//my-sap-cong-bo-80000-tra...  Thế giới
# 2  https://thanhnien.vn//israel-bat-ngo-tan-cong-...  Thế giới
#
#                  Date                                  Writer  \
# 0 2025-03-18 09:47:00  Văn Khoa - truongvankhoa2001@yahoo.com
# 1 2025-03-18 08:20:00             Trí Đỗ - mtri1904@gmail.com
# 2 2025-03-18 08:19:00       Khánh An - khanhanpress@gmail.com
#
#                                              Content
# 0  Tổng thống Mỹ Donald Trump ngày 17.3 đã thu hồ...
# ...

# %%
df = pd.DataFrame(IMAGE)
df
# Out:
#                           ImageID  \
# 0  -biden-17422627851151634799935
# 1  justice-1742260388626230757972
# 2  israel-17422598753511573087989
#
#                                             ImageUrl  \
# 0  https://images2.thanhnien.vn/52806826363704524...
# 1  https://images2.thanhnien.vn/52806826363704524...
# 2  https://images2.thanhnien.vn/52806826363704524...
#
#                                           Decription             Source
# 0  Ông Joe Biden và ông Hunter Biden ở Nantucket ...           Ảnh: AFP
# 1                         Tổng thống Mỹ Donald Trump           ảnh: afp
# 2  Khói bốc lên trong các cuộc không kích vào Raf...  ẢNH MINH HỌA: AFP

# %%
df = pd.DataFrame(ARTICLE_IMAGE)
df
# Out:
#                  ArticleID                         ImageID
# 0  biden-18525031808505304  -biden-17422627851151634799935
# 1  nedy-185250318081459953  justice-1742260388626230757972
# 2  dich-185250318080545601  israel-17422598753511573087989

# %%
df = pd.DataFrame(VIDEO)
df
# Out:
#                           VideoID  \
# 0  o-hieu-17422274112182050754497
# 1  ugh-cut-1742267428124675523165
#
#                                             VideoUrl  \
# 0  https://thanhnien.mediacdn.vn/3250849520458178...
# 1  https://thanhnien.mediacdn.vn/3250849520458178...
#
#                                           Decription
# 0  Vì sao Tổng thống Trump tuyên bố loạt lệnh ân ...
# 1  Tiếng nổ và chớp lửa bùng lên từ những vụ khôn...

# %%
df = pd.DataFrame(ARTICLE_VIDEO)
df
# Out:
#                  ArticleID                         VideoID
# 0  biden-18525031808505304  o-hieu-17422274112182050754497
# 1  nedy-185250318081459953  o-hieu-17422274112182050754497
# 2  dich-185250318080545601  ugh-cut-1742267428124675523165

# %%
list_Category = ['the-gioi', 'kinh-te', 'chinh-tri', 'thoi-su', 'doi-song', 'suc-khoe', 'gioi-tre', 'giao-duc', 'du-lich', 'van-hoa', 'cong-nghe']


ARTICLE = []
ARTICLE_IMAGE = []
IMAGE = []
image_ids = set()  # tạo tập hợp để lưu các ImageID đã có (cách này chắc nhanh hơn)
ARTICLE_VIDEO = []
VIDEO = []
video_ids = set()  # tạo tập hợp để lưu các VideoID đã có (cách này chắc nhanh hơn)


headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

#for category in list_Category[:5]:
for category in list_Category:

    response = requests.get(f'https://thanhnien.vn/{category}.htm', headers=headers) 
    print(f'https://thanhnien.vn/{category}.htm')
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    raw_listing_news = soup.find_all('div', {'class':'box-category-item'})
    
    for raw_Item_news in raw_listing_news[:2]:
        ARTICLE_dict = {}
        #ARTICLE_IMAGE_dict = {}
        #IMAGE_dict = {}
        #ARTICLE_VIDEO_dict = {}
        #VIDEO_dict = {}
        
        href_article = 'https://thanhnien.vn/' + raw_Item_news.find('a', {'class':'box-category-link-with-avatar img-resize'})['href']
        print('    ' + href_article)
        try:
            response = requests.get(href_article, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')
        
            ARTICLE_dict['ArticleID'] = href_article[-27:].replace('.htm', '')
            ARTICLE_dict['Title'] = soup.title.text
            ARTICLE_dict['Url'] = href_article
            ARTICLE_dict['Category'] = soup.find('a', {'class':'category-page__name'}).text
            ARTICLE_dict['Date'] = soup.find('div', {'class':'detail-time'}).text.strip()[:-6]
            ARTICLE_dict['Writer'] = soup.find('div', {'class':'author-info-top'}).text.strip().replace('\n',' ').replace('  ',' ')
                            #ARTICLE_dict['Audio'] = soup.find('div', {'class':'detail-cmain'})
                            #print(soup.find('div', {'class':'detail-content afcbc-body'}).text.strip())
                            #print((soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']))
            content = soup.find('h2', {'class':'detail-sapo'}).text.strip() + "\n"
            for i in (soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']):
                content += i.text.strip() + "\n"
                            #print(content)
            ARTICLE_dict['Content'] = content
        
            main_frame = soup.find('div', {'class':'detail-cmain'})
                            # print(main_frame.find_all('img'))
                            # print(main_frame.find('img')['data-original'])
                            # print(len(main_frame.find_all('img')))
                            # a=0
                            # for i in (main_frame.find_all('img')):
                            #     #if 'data-original' in i.attrs:
                            #     if i.get('data-original'):
                            #         a+=1
                            # print(a)
            
            for i in (main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})):
                IMAGE_dict = {}
                ARTICLE_IMAGE_dict = {}
                IMAGE_dict["ImageID"] = i.find('img').get('data-original').strip()[-34:].replace('.jpg','')
                IMAGE_dict["ImageUrl"] = i.find('img').get('data-original').strip()
                IMAGE_dict["Decription"] = i.find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip()
                IMAGE_dict["Source"] = i.find('div', {'class':'PhotoCMS_Author'}).text.strip()
                            # print(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'}))
                            # print(len(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})))
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('img').get('data-original'))
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip())
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('div', {'class':'PhotoCMS_Author'}).text.strip())
                #print(IMAGE_dict)
                # if not IMAGE or not any(d["ImageID"] == IMAGE_dict["ImageID"] for d in IMAGE):
                    # IMAGE.append(IMAGE_dict)
                if IMAGE_dict["ImageID"] not in image_ids:
                    IMAGE.append(IMAGE_dict)
                    image_ids.add(IMAGE_dict["ImageID"])
                ARTICLE_IMAGE_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                ARTICLE_IMAGE_dict["ImageID"] = IMAGE_dict["ImageID"]
                ARTICLE_IMAGE.append(ARTICLE_IMAGE_dict)
        
                            # print(len(main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                            # print((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                            # print('https://'+((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'}))[0]['data-vid']).strip())
            for i in (main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})):
                VIDEO_dict = {}
                ARTICLE_VIDEO_dict = {}
                VIDEO_dict["VideoID"] = i['data-vid'].strip()[-34:].replace('.mp4','')
                VIDEO_dict["VideoUrl"] = 'https://'+ i['data-vid'].strip()
                VIDEO_dict["Decription"] = i.find('div', {'class':'VideoCMS_Caption'}).text.strip()
                if VIDEO_dict["VideoID"] not in video_ids:
                    VIDEO.append(VIDEO_dict)
                    video_ids.add(VIDEO_dict["VideoID"])
                ARTICLE_VIDEO_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                ARTICLE_VIDEO_dict["VideoID"] = VIDEO_dict["VideoID"]
                ARTICLE_VIDEO.append(ARTICLE_VIDEO_dict)
        
            
            ARTICLE.append(ARTICLE_dict)
        
        #print(ARTICLE)
        #print(IMAGE)
        #print(ARTICLE_IMAGE)
        #print(VIDEO)
        #print(ARTICLE_VIDEO)

        except Exception as e:
            print(f"        {e}. Có thể bài đăng đã bị gỡ xuống")
        
        #break
    #break

#print(ARTICLE)
#print(IMAGE)
#print(ARTICLE_IMAGE)
#print(VIDEO)
#print(ARTICLE_VIDEO)
# Out:
# https://thanhnien.vn/the-gioi.htm
#     https://thanhnien.vn//trung-quoc-trien-khai-gan-60-may-bay-sau-phat-ngon-cua-lanh-dao-dai-loan-185250318103542377.htm
#     https://thanhnien.vn//israel-tham-van-my-truoc-khi-tan-cong-it-nhat-200-nguoi-thiet-mang-o-gaza-185250318100820037.htm
# https://thanhnien.vn/kinh-te.htm
#     https://thanhnien.vn//gia-usd-hom-nay-1832025-dong-loat-tang-185250318081341531.htm
#     https://thanhnien.vn//vang-tang-cao-ky-luc-rui-ro-du-dinh-185250317232642333.htm
#         'NoneType' object has no attribute 'text'. Có thể bài đăng đã bị gỡ xuống
# https://thanhnien.vn/chinh-tri.htm
#     https://thanhnien.vn//tong-bi-thu-sap-xep-bo-may-don-vi-hanh-chinh-la-co-hoi-sang-loc-can-bo-185250317153514466.htm
#     https://thanhnien.vn//mang-xa-hoi-dang-tro-thanh-quyen-luc-tiem-an-voi-tu-tuong-hang-trieu-nguoi-viet-18525031711380569.htm
# https://thanhnien.vn/thoi-su.htm
# ...

# %%
df = pd.DataFrame(ARTICLE)
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M')
df
# Out:
#                   ArticleID  \
# 0   loan-185250318103542377
# 1   gaza-185250318100820037
# 2   tang-185250318081341531
# 3   n-bo-185250317153514466
# 4   -viet-18525031711380569
# 5   h-da-185250318010943409
# 6   hanh-185250317171736004
# 7   -nho-185250316232410665
# 8   -sau-185250317224932888
# 9   -nam-185250317190951355
# 10  -voi-185250317190606901
# 11  2025-185250318070241713
# 12  ng-6-185250318093035909
# 13  bong-185250317112648577
# 14  bong-185250317174950935
# 15  gioi-185250317224443928
# 16  -sao-185250317224923014
# 17  soft-185250314101921253
# 18  2025-185250318050509384
#
#                                                 Title  \
# 0   Trung Quốc triển khai gần 60 máy bay sau phát ...
# 1   Israel tham vấn Mỹ trước khi tấn công, ít nhất...
# 2           Giá USD hôm nay 18.3.2025: Đồng loạt tăng
# 3   Tổng Bí thư: Sắp xếp bộ máy, đơn vị hành chính...
# 4   'Mạng xã hội đang trở thành quyền lực tiềm ẩn ...
# 5   Điều tra nguyên nhân vụ cháy 7 ki ốt ở chợ Tha...
# ...

# %%
list_Category = ['the-gioi', 'kinh-te', 'chinh-tri', 'thoi-su', 'doi-song', 'suc-khoe', 'gioi-tre', 'giao-duc', 'du-lich', 'van-hoa', 'tieu-dung-thong-minh', 'cong-nghe']


ARTICLE = []
ARTICLE_IMAGE = []
IMAGE = []
image_ids = set()  # tạo tập hợp để lưu các ImageID đã có (cách này chắc nhanh hơn)
ARTICLE_VIDEO = []
VIDEO = []
video_ids = set()  # tạo tập hợp để lưu các VideoID đã có (cách này chắc nhanh hơn)


headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

#for category in list_Category[:5]:
for category in list_Category:

    response = requests.get(f'https://thanhnien.vn/{category}.htm', headers=headers) 
    print(f'https://thanhnien.vn/{category}.htm')
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    raw_listing_news = soup.find_all('div', {'class':'box-category-item'})
    
    for raw_Item_news in raw_listing_news[:2]:
        ARTICLE_dict = {}
        #ARTICLE_IMAGE_dict = {}
        #IMAGE_dict = {}
        #ARTICLE_VIDEO_dict = {}
        #VIDEO_dict = {}
        
        href_article = 'https://thanhnien.vn/' + raw_Item_news.find('a', {'class':'box-category-link-with-avatar img-resize'})['href']
        print('    ' + href_article)
        try:
            response = requests.get(href_article, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')
        
            ARTICLE_dict['ArticleID'] = href_article[-27:].replace('.htm', '')
            ARTICLE_dict['Title'] = soup.title.text
            ARTICLE_dict['Url'] = href_article
            ARTICLE_dict['Category'] = soup.find('a', {'class':'category-page__name'}).text
            ARTICLE_dict['Date'] = soup.find('div', {'class':'detail-time'}).text.strip()[:-6]
            ARTICLE_dict['Writer'] = soup.find('div', {'class':'author-info-top'}).text.strip().replace('\n',' ').replace('  ',' ')
                            #ARTICLE_dict['Audio'] = soup.find('div', {'class':'detail-cmain'})
                            #print(soup.find('div', {'class':'detail-content afcbc-body'}).text.strip())
                            #print((soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']))
            content = soup.find('h2', {'class':'detail-sapo'}).text.strip() + "\n"
            for i in (soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']):
                content += i.text.strip() + "\n"
                            #print(content)
            ARTICLE_dict['Content'] = content
        
            main_frame = soup.find('div', {'class':'detail-cmain'})
                            # print(main_frame.find_all('img'))
                            # print(main_frame.find('img')['data-original'])
                            # print(len(main_frame.find_all('img')))
                            # a=0
                            # for i in (main_frame.find_all('img')):
                            #     #if 'data-original' in i.attrs:
                            #     if i.get('data-original'):
                            #         a+=1
                            # print(a)
            
            for i in (main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})):
                IMAGE_dict = {}
                ARTICLE_IMAGE_dict = {}
                IMAGE_dict["ImageID"] = i.find('img').get('data-original').strip()[-34:].replace('.jpg','').replace('.jpeg','').replace('.png','')
                IMAGE_dict["ImageUrl"] = i.find('img').get('data-original').strip()
                IMAGE_dict["Decription"] = i.find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip()
                IMAGE_dict["Source"] = i.find('div', {'class':'PhotoCMS_Author'}).text.strip()
                            # print(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'}))
                            # print(len(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})))
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('img').get('data-original'))
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip())
                            # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('div', {'class':'PhotoCMS_Author'}).text.strip())
                #print(IMAGE_dict)
                # if not IMAGE or not any(d["ImageID"] == IMAGE_dict["ImageID"] for d in IMAGE):
                    # IMAGE.append(IMAGE_dict)
                if IMAGE_dict["ImageID"] not in image_ids:
                    IMAGE.append(IMAGE_dict)
                    image_ids.add(IMAGE_dict["ImageID"])
                ARTICLE_IMAGE_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                ARTICLE_IMAGE_dict["ImageID"] = IMAGE_dict["ImageID"]
                ARTICLE_IMAGE.append(ARTICLE_IMAGE_dict)
        
                            # print(len(main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                            # print((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                            # print('https://'+((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'}))[0]['data-vid']).strip())
            for i in (main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})):
                VIDEO_dict = {}
                ARTICLE_VIDEO_dict = {}
                VIDEO_dict["VideoID"] = i['data-vid'].strip()[-34:].replace('.mp4','')
                VIDEO_dict["VideoUrl"] = 'https://'+ i['data-vid'].strip()
                VIDEO_dict["Decription"] = i.find('div', {'class':'VideoCMS_Caption'}).text.strip()
                if VIDEO_dict["VideoID"] not in video_ids:
                    VIDEO.append(VIDEO_dict)
                    video_ids.add(VIDEO_dict["VideoID"])
                ARTICLE_VIDEO_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                ARTICLE_VIDEO_dict["VideoID"] = VIDEO_dict["VideoID"]
                ARTICLE_VIDEO.append(ARTICLE_VIDEO_dict)
        
            
            ARTICLE.append(ARTICLE_dict)
        
        #print(ARTICLE)
        #print(IMAGE)
        #print(ARTICLE_IMAGE)
        #print(VIDEO)
        #print(ARTICLE_VIDEO)

        except Exception as e:
            print("        keep going...")
        
        #break
    #break

#print(ARTICLE)
#print(IMAGE)
#print(ARTICLE_IMAGE)
#print(VIDEO)
#print(ARTICLE_VIDEO)
# Out:
# https://thanhnien.vn/the-gioi.htm
#     https://thanhnien.vn//chinh-quyen-ong-trump-tranh-cai-voi-tham-phan-ve-vu-truc-xuat-nguoi-185250318102836036.htm
#     https://thanhnien.vn//trung-quoc-trien-khai-gan-60-may-bay-sau-phat-ngon-cua-lanh-dao-dai-loan-185250318103542377.htm
# https://thanhnien.vn/kinh-te.htm
#     https://thanhnien.vn//gia-usd-hom-nay-1832025-dong-loat-tang-185250318081341531.htm
#     https://thanhnien.vn//vang-tang-cao-ky-luc-rui-ro-du-dinh-185250317232642333.htm
#         keep going...
# https://thanhnien.vn/chinh-tri.htm
#     https://thanhnien.vn//tong-bi-thu-sap-xep-bo-may-don-vi-hanh-chinh-la-co-hoi-sang-loc-can-bo-185250317153514466.htm
#     https://thanhnien.vn//mang-xa-hoi-dang-tro-thanh-quyen-luc-tiem-an-voi-tu-tuong-hang-trieu-nguoi-viet-18525031711380569.htm
# https://thanhnien.vn/thoi-su.htm
#     https://thanhnien.vn//dieu-tra-nguyen-nhan-vu-chay-7-ki-ot-o-cho-thanh-da-185250318010943409.htm
# ...

# %%
df = pd.DataFrame(ARTICLE)
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M')
df
# Out:
#                   ArticleID  \
# 0   guoi-185250318102836036
# 1   loan-185250318103542377
# 2   tang-185250318081341531
# 3   n-bo-185250317153514466
# 4   -viet-18525031711380569
# 5   h-da-185250318010943409
# 6   hanh-185250317171736004
# 7   -nho-185250316232410665
# 8   -sau-185250317224932888
# 9   hong-185250314173809093
# 10  -nam-185250317190951355
# 11  -voi-185250317190606901
# 12  2025-185250318070241713
# 13  ng-6-185250318093035909
# 14  bong-185250317112648577
# 15  bong-185250317174950935
# 16  gioi-185250317224443928
# 17  -sao-185250317224923014
# 18  loat-185250318080707749
# 19  n-an-185250314192446633
# 20  soft-185250314101921253
# 21  2025-185250318050509384
#
#                                                 Title  \
# 0   Chính quyền ông Trump tranh cãi với thẩm phán ...
# 1   Trung Quốc triển khai gần 60 máy bay sau phát ...
# 2           Giá USD hôm nay 18.3.2025: Đồng loạt tăng
# 3   Tổng Bí thư: Sắp xếp bộ máy, đơn vị hành chính...
# ...

# %%
df = pd.DataFrame(IMAGE)
df['Decription'] = df['Decription'].replace('', 'No Description')
df['Source'] = df['Source'].replace('', 'No Source')
df
# Out:
#                                ImageID  \
# 0       alvador-1742268682388345745260
# 1       ien-tap-1742269292516375107249
# 2       c-thang-1742261754209787703280
# 3       916635-17422003646101537991948
# 4       7916632-1742200364605666331861
# 5       7916960-1742189856546338403713
# 6       7916966-1742189957075369612315
# 7       09f646-17422344873631541957443
# 8       0a519ea-1742234487215400099205
# 9       ddb4494-1742234547412677504682
# 10      18e557-17422344873891863118869
# 11      9902d6-17422344872461978808705
# 12      466038-17422267315761392700611
# 13      134c7f-17422266575001552888201
# 14      -duong-17041838668131235532777
# 15      /3/16/1-1742142012827680271474
# 16      /3/16/2-1742142012862242943802
# 17      5/3/16/3-174214206141771339263
# 18  6/box-17421420188482141897381.jpeg
# 19      h-ngot-17416935693132051257738
# 20  7/di-bo-1742203475906768533205.png
# 21      1-anh1-1-174220434279689031362
# 22      un-rong-1741948337039318704924
# ...

# %%
IMAGE
# Out:
# [{'ImageID': 'alvador-1742268682388345745260',
#   'ImageUrl': 'https://images2.thanhnien.vn/528068263637045248/2025/3/18/2025-03-16t233151z-411712005-rc25edau5ikf-rtrmadp-3-usa-trump-migration-el-salvador-1742268682388345745260.jpg',
#   'Decription': 'Cảnh sát El Salvador áp giải thành viên nhóm Tren de Aragua bị Mỹ trục xuất ngày 16.3',
#   'Source': 'ẢNH: REUTERS'},
#  {'ImageID': 'ien-tap-1742269292516375107249',
#   'ImageUrl': 'https://images2.thanhnien.vn/528068263637045248/2025/3/18/chien-dau-co-trung-quoc-trong-mot-cuoc-dien-tap-1742269292516375107249.jpg',
#   'Decription': 'Chiến đấu cơ Trung Quốc trong một cuộc diễn tập',
#   'Source': 'Ảnh: Chụp màn hình chinamil.com.cn'},
#  {'ImageID': 'c-thang-1742261754209787703280',
#   'ImageUrl': 'https://images2.thanhnien.vn/528068263637045248/2025/3/18/tien-do-cua-ngoc-thang-1742261754209787703280.jpg',
#   'Decription': 'Giá USD sáng 18.3 đồng loạt tăng',
#   'Source': 'ẢNH: NGỌC THẮNG'},
# ...

# %%
df = pd.DataFrame(IMAGE)
df['Decription'] = df['Decription'].replace('', 'No Description')
df['Source'] = df['Source'].replace('', 'No Source')
df
# Out:
#                                ImageID  \
# 0       alvador-1742268682388345745260
# 1       ien-tap-1742269292516375107249
# 2       c-thang-1742261754209787703280
# 3       916635-17422003646101537991948
# 4       7916632-1742200364605666331861
# 5       7916960-1742189856546338403713
# 6       7916966-1742189957075369612315
# 7       09f646-17422344873631541957443
# 8       0a519ea-1742234487215400099205
# 9       ddb4494-1742234547412677504682
# 10      18e557-17422344873891863118869
# 11      9902d6-17422344872461978808705
# 12      466038-17422267315761392700611
# 13      134c7f-17422266575001552888201
# 14      -duong-17041838668131235532777
# 15      /3/16/1-1742142012827680271474
# 16      /3/16/2-1742142012862242943802
# 17      5/3/16/3-174214206141771339263
# 18  6/box-17421420188482141897381.jpeg
# 19      h-ngot-17416935693132051257738
# 20  7/di-bo-1742203475906768533205.png
# 21      1-anh1-1-174220434279689031362
# 22      un-rong-1741948337039318704924
# ...

# %%
df.to_csv(r'C:\Users\Admin\Downloads\IMAGE.csv',
         index=False, encoding='utf-8-sig')

# %%
import pandas as pd

# Giả sử có hai DataFrame df1 và df2
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'X': ['a', 'b', 'c'], 'Y': ['d', 'e', 'f']})

# Lưu vào Excel với nhiều sheet
file_path = r'C:\Users\Admin\Downloads\my_data.xlsx'
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    df1.to_excel(writer, sheet_name='Sheet1', index=False)
    df2.to_excel(writer, sheet_name='Sheet2', index=False)

print(f'Data saved to {file_path}')
# Out:
# Data saved to C:\Users\Admin\Downloads\my_data.xlsx

# %%
file_path = r'C:\Users\Admin\Downloads\my_data.xlsx'
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
    
print(f'Data saved to {file_path}')
# Out:
# Data saved to C:\Users\Admin\Downloads\my_data.xlsx

# %%
list_Category = ['the-gioi', 'kinh-te', 'chinh-tri', 'thoi-su', 'doi-song', 'suc-khoe', 'gioi-tre', 'giao-duc', 'du-lich', 'van-hoa', 'tieu-dung-thong-minh', 'cong-nghe']


ARTICLE = []
ARTICLE_IMAGE = []
IMAGE = []
image_ids = set()  # tạo tập hợp để lưu các ImageID đã có (cách này chắc nhanh hơn)
ARTICLE_VIDEO = []
VIDEO = []
video_ids = set()  # tạo tập hợp để lưu các VideoID đã có (cách này chắc nhanh hơn)


headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
}

#for category in list_Category[:5]:
for category in list_Category:

    response = requests.get(f'https://thanhnien.vn/{category}.htm', headers=headers) 
    print(f'https://thanhnien.vn/{category}.htm')
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    raw_listing_news = soup.find_all('div', {'class':'box-category-item'})
    
    #for raw_Item_news in raw_listing_news[:2]:
    for raw_Item_news in raw_listing_news:
        ARTICLE_dict = {}
        #ARTICLE_IMAGE_dict = {}
        #IMAGE_dict = {}
        #ARTICLE_VIDEO_dict = {}
        #VIDEO_dict = {}
        
        try:
            href_article = 'https://thanhnien.vn/' + raw_Item_news.find('a', {'class':'box-category-link-with-avatar img-resize'})['href']
            print('    ' + href_article)
            try:
                response = requests.get(href_article, headers=headers)
                soup = BeautifulSoup(response.text, 'html.parser')
            
                ARTICLE_dict['ArticleID'] = href_article[-27:].replace('.htm', '')
                ARTICLE_dict['Title'] = soup.title.text
                ARTICLE_dict['Url'] = href_article
                ARTICLE_dict['Category'] = soup.find('a', {'class':'category-page__name'}).text
                ARTICLE_dict['Date'] = soup.find('div', {'class':'detail-time'}).text.strip()[:-6]
                ARTICLE_dict['Writer'] = soup.find('div', {'class':'author-info-top'}).text.strip().replace('\n',' ').replace('  ',' ')
                                #ARTICLE_dict['Audio'] = soup.find('div', {'class':'detail-cmain'})
                                #print(soup.find('div', {'class':'detail-content afcbc-body'}).text.strip())
                                #print((soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']))
                content = soup.find('h2', {'class':'detail-sapo'}).text.strip() + "\n"
                for i in (soup.find('div', {'class':'detail-content afcbc-body'})).find_all(['p','h2']):
                    content += i.text.strip() + "\n"
                                #print(content)
                ARTICLE_dict['Content'] = content
            
                main_frame = soup.find('div', {'class':'detail-cmain'})
                                # print(main_frame.find_all('img'))
                                # print(main_frame.find('img')['data-original'])
                                # print(len(main_frame.find_all('img')))
                                # a=0
                                # for i in (main_frame.find_all('img')):
                                #     #if 'data-original' in i.attrs:
                                #     if i.get('data-original'):
                                #         a+=1
                                # print(a)
                
                for i in (main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})):
                    IMAGE_dict = {}
                    ARTICLE_IMAGE_dict = {}
                    IMAGE_dict["ImageID"] = i.find('img').get('data-original').strip()[-34:].replace('.jpg','').replace('.jpeg','').replace('.png','')
                    IMAGE_dict["ImageUrl"] = i.find('img').get('data-original').strip()
                    IMAGE_dict["Decription"] = i.find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip()
                    IMAGE_dict["Source"] = i.find('div', {'class':'PhotoCMS_Author'}).text.strip()
                                # print(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'}))
                                # print(len(main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})))
                                # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('img').get('data-original'))
                                # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('figcaption', {'class':'PhotoCMS_Caption'}).text.strip())
                                # print((main_frame.find_all('figure', {'class':'VCSortableInPreviewMode', 'type':'Photo'})[0]).find('div', {'class':'PhotoCMS_Author'}).text.strip())
                    #print(IMAGE_dict)
                    # if not IMAGE or not any(d["ImageID"] == IMAGE_dict["ImageID"] for d in IMAGE):
                        # IMAGE.append(IMAGE_dict)
                    if IMAGE_dict["ImageID"] not in image_ids:
                        IMAGE.append(IMAGE_dict)
                        image_ids.add(IMAGE_dict["ImageID"])
                    ARTICLE_IMAGE_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                    ARTICLE_IMAGE_dict["ImageID"] = IMAGE_dict["ImageID"]
                    ARTICLE_IMAGE.append(ARTICLE_IMAGE_dict)
            
                                # print(len(main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                                # print((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})))
                                # print('https://'+((main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'}))[0]['data-vid']).strip())
                for i in (main_frame.find_all('div', {'class':'VCSortableInPreviewMode', 'type':'VideoStream'})):
                    VIDEO_dict = {}
                    ARTICLE_VIDEO_dict = {}
                    VIDEO_dict["VideoID"] = i['data-vid'].strip()[-34:].replace('.mp4','')
                    VIDEO_dict["VideoUrl"] = 'https://'+ i['data-vid'].strip()
                    VIDEO_dict["Decription"] = i.find('div', {'class':'VideoCMS_Caption'}).text.strip()
                    if VIDEO_dict["VideoID"] not in video_ids:
                        VIDEO.append(VIDEO_dict)
                        video_ids.add(VIDEO_dict["VideoID"])
                    ARTICLE_VIDEO_dict["ArticleID"] = ARTICLE_dict['ArticleID']
                    ARTICLE_VIDEO_dict["VideoID"] = VIDEO_dict["VideoID"]
                    ARTICLE_VIDEO.append(ARTICLE_VIDEO_dict)
            
                
                ARTICLE.append(ARTICLE_dict)
            
            #print(ARTICLE)
            #print(IMAGE)
            #print(ARTICLE_IMAGE)
            #print(VIDEO)
            #print(ARTICLE_VIDEO)
    
            except Exception as e:
                print("        keep going...")
            
            #break
        except Exception as e:
                print("        keep going...")
    #break

#print(ARTICLE)
#print(IMAGE)
#print(ARTICLE_IMAGE)
#print(VIDEO)
#print(ARTICLE_VIDEO)
# Out:
# https://thanhnien.vn/the-gioi.htm
#     https://thanhnien.vn//nha-khoa-hoc-tuyen-bo-tim-ra-xac-may-bay-mh370-185250318124157703.htm
#     https://thanhnien.vn//trung-quoc-san-sang-tham-gia-tai-thiet-hau-xung-dot-o-ukraine-185250318112647991.htm
#     https://thanhnien.vn//chinh-quyen-ong-trump-tranh-cai-voi-tham-phan-ve-vu-truc-xuat-nguoi-185250318102836036.htm
#     https://thanhnien.vn//trung-quoc-trien-khai-gan-60-may-bay-sau-phat-ngon-cua-lanh-dao-dai-loan-185250318103542377.htm
#     https://thanhnien.vn//israel-tham-van-my-truoc-khi-tan-cong-it-nhat-200-nguoi-thiet-mang-o-gaza-185250318100820037.htm
#     https://thanhnien.vn//nhat-sap-trien-khai-them-ten-lua-tam-xa-vi-so-my-giam-cam-ket-185250318090048616.htm
#         keep going...
#     https://thanhnien.vn//my-sap-cong-bo-80000-trang-tai-lieu-ve-vu-am-sat-tong-thong-kennedy-185250318081459953.htm
#     https://thanhnien.vn//israel-bat-ngo-tan-cong-khap-gaza-tuyen-bo-day-manh-chien-dich-185250318080545601.htm
# ...

# %%
df_ARTICLE = pd.DataFrame(ARTICLE)
df_ARTICLE
# Out:
#                    ArticleID  \
# 0    h370-185250318124157703
# 1    aine-185250318112647991
# 2    guoi-185250318102836036
# 3    loan-185250318103542377
# 4    gaza-185250318100820037
# ..                       ...
# 281  -dao-185250317170500719
# 282  tien-185250313230514292
# 283  ao-bi-18525031512210285
# 284  -ram-185250317071417069
# 285  -nam-185250317124927224
#
#                                                  Title  \
# 0       Nhà khoa học tuyên bố tìm ra xác máy bay MH370
# 1    Trung Quốc sẵn sàng tham gia tái thiết Ukraine...
# 2    Chính quyền ông Trump tranh cãi với thẩm phán ...
# 3    Trung Quốc triển khai gần 60 máy bay sau phát ...
# 4    Israel tham vấn Mỹ trước khi tấn công, ít nhất...
# ..                                                 ...
# 281  Ông chủ Samsung ra mệnh lệnh thép cho giới lãn...
# 282  Mỹ phạt sàn OKX nửa tỉ USD tội vi phạm luật ch...
# 283  Thúc đẩy đổi mới sáng tạo trong ngành chế biến...
# ...

# %%
df_ARTICLE = pd.DataFrame(ARTICLE)
#df_ARTICLE['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M')
#df_ARTICLE

df_IMAGE = pd.DataFrame(IMAGE)
df_IMAGE['Decription'] = df_IMAGE['Decription'].replace('', 'No Description')
df_IMAGE['Source'] = df_IMAGE['Source'].replace('', 'No Source')
#df_IMAGE
df_ARTICLE_IMAGE = pd.DataFrame(ARTICLE_IMAGE)
#df_ARTICLE_IMAGE

df_VIDEO = pd.DataFrame(VIDEO)
df_VIDEO['Decription'] = df_VIDEO['Decription'].replace('', 'No Description')
#df_VIDEO
df_ARTICLE_VIDEO = pd.DataFrame(ARTICLE_VIDEO)
#df_ARTICLE_VIDEO



# df_ARTICLE.to_csv(r'C:\Users\Admin\Downloads\ARTICLE.csv',
#          index=False, encoding='utf-8-sig')
# df_IMAGE.to_csv(r'C:\Users\Admin\Downloads\IMAGE.csv',
#          index=False, encoding='utf-8-sig')
# df_ARTICLE_IMAGE.to_csv(r'C:\Users\Admin\Downloads\ARTICLE_IMAGE.csv',
#          index=False, encoding='utf-8-sig')
# df_VIDEO.to_csv(r'C:\Users\Admin\Downloads\VIDEO.csv',
#          index=False, encoding='utf-8-sig')
# df_ARTICLE_VIDEO.to_csv(r'C:\Users\Admin\Downloads\ARTICLE_VIDEO.csv',
#          index=False, encoding='utf-8-sig')

file_path = r'C:\Users\Admin\Downloads\ArticleDataset.xlsx'
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    df_ARTICLE.to_excel(writer, sheet_name='ARTICLE', index=False)
    df_IMAGE.to_excel(writer, sheet_name='IMAGE', index=False)
    df_ARTICLE_IMAGE.to_excel(writer, sheet_name='ARTICLE_IMAGE', index=False)
    df_VIDEO.to_excel(writer, sheet_name='VIDEO', index=False)
    df_ARTICLE_VIDEO.to_excel(writer, sheet_name='ARTICLE_VIDEO', index=False)
    
    
    
print(f'Data saved to {file_path}')
# Out:
# Data saved to C:\Users\Admin\Downloads\ArticleDataset.xlsx

# %%
df_ARTICLE = pd.DataFrame(ARTICLE)
df_ARTICLE['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M')
df_ARTICLE['Date'] = df_ARTICLE['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')
df_ARTICLE
# Out:
#                    ArticleID  \
# 0    h370-185250318124157703
# 1    aine-185250318112647991
# 2    guoi-185250318102836036
# 3    loan-185250318103542377
# 4    gaza-185250318100820037
# ..                       ...
# 281  -dao-185250317170500719
# 282  tien-185250313230514292
# 283  ao-bi-18525031512210285
# 284  -ram-185250317071417069
# 285  -nam-185250317124927224
#
#                                                  Title  \
# 0       Nhà khoa học tuyên bố tìm ra xác máy bay MH370
# 1    Trung Quốc sẵn sàng tham gia tái thiết Ukraine...
# 2    Chính quyền ông Trump tranh cãi với thẩm phán ...
# 3    Trung Quốc triển khai gần 60 máy bay sau phát ...
# 4    Israel tham vấn Mỹ trước khi tấn công, ít nhất...
# ..                                                 ...
# 281  Ông chủ Samsung ra mệnh lệnh thép cho giới lãn...
# 282  Mỹ phạt sàn OKX nửa tỉ USD tội vi phạm luật ch...
# 283  Thúc đẩy đổi mới sáng tạo trong ngành chế biến...
# ...

# %%
ARTICLE[-1]
# Out:
# {'ArticleID': '-nam-185250317124927224',
#  'Title': 'D’Xavier đưa eSports Việt Nam thống trị PUBG MOBILE Đông Nam Á sau 3 năm',
#  'Url': 'https://thanhnien.vn//dxavier-dua-esports-viet-nam-thong-tri-pubg-mobile-dong-nam-a-sau-3-nam-185250317124927224.htm',
#  'Category': 'Công nghệ',
#  'Date': '17/03/2025 15:49',
#  'Writer': 'Tuấn Anh - tuananh.intro@gmail.com',
# ...

# %%
ARTICLE[0]
# Out:
# {'ArticleID': 'h370-185250318124157703',
#  'Title': 'Nhà khoa học tuyên bố tìm ra xác máy bay MH370',
#  'Url': 'https://thanhnien.vn//nha-khoa-hoc-tuyen-bo-tim-ra-xac-may-bay-mh370-185250318124157703.htm',
#  'Category': 'Thế giới',
#  'Date': '18/03/2025 12:48',
#  'Writer': 'Trí Đỗ - mtri1904@gmail.com',
# ...

# %%
import pandas as pd

# Tạo DataFrame từ dữ liệu ARTICLE
df_ARTICLE = pd.DataFrame(ARTICLE)

# Kiểm tra xem có giá trị NaN hoặc trống trong cột Date không
print(df_ARTICLE['Date'].isnull().sum())  # Xem có bao nhiêu giá trị NaN

# Loại bỏ khoảng trắng dư thừa (nếu có)
df_ARTICLE['Date'] = df_ARTICLE['Date'].astype(str).str.strip()

# Thử chuyển đổi, xử lý lỗi bằng errors='coerce' để tránh NaN do lỗi format
df_ARTICLE['Date'] = pd.to_datetime(df_ARTICLE['Date'], format='%d/%m/%Y %H:%M', errors='coerce')

# Xem lại các giá trị bị NaT
print(df_ARTICLE[df_ARTICLE['Date'].isna()])  # Kiểm tra những dòng bị lỗi

# Chuyển về dạng chuẩn SQL Server
df_ARTICLE['Date'] = df_ARTICLE['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')

# Kiểm tra kết quả
df_ARTICLE
# Out:
# 0
# Empty DataFrame
# Columns: [ArticleID, Title, Url, Category, Date, Writer, Content]
# Index: []
#                    ArticleID  \
# 0    h370-185250318124157703
# 1    aine-185250318112647991
# 2    guoi-185250318102836036
# 3    loan-185250318103542377
# 4    gaza-185250318100820037
# ..                       ...
# 281  -dao-185250317170500719
# 282  tien-185250313230514292
# 283  ao-bi-18525031512210285
# 284  -ram-185250317071417069
# 285  -nam-185250317124927224
#
#                                                  Title  \
# 0       Nhà khoa học tuyên bố tìm ra xác máy bay MH370
# 1    Trung Quốc sẵn sàng tham gia tái thiết Ukraine...
# 2    Chính quyền ông Trump tranh cãi với thẩm phán ...
# 3    Trung Quốc triển khai gần 60 máy bay sau phát ...
# 4    Israel tham vấn Mỹ trước khi tấn công, ít nhất...
# ..                                                 ...
# 281  Ông chủ Samsung ra mệnh lệnh thép cho giới lãn...
# 282  Mỹ phạt sàn OKX nửa tỉ USD tội vi phạm luật ch...
# ...

# %%
df_ARTICLE = pd.DataFrame(ARTICLE)
df_ARTICLE['Date'] = df_ARTICLE['Date'].astype(str).str.strip()
df_ARTICLE['Date'] = pd.to_datetime(df_ARTICLE['Date'], format='%d/%m/%Y %H:%M', errors='coerce')
df_ARTICLE['Date'] = df_ARTICLE['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')
#df_ARTICLE

df_IMAGE = pd.DataFrame(IMAGE)
df_IMAGE['Decription'] = df_IMAGE['Decription'].replace('', 'No Description')
df_IMAGE['Source'] = df_IMAGE['Source'].replace('', 'No Source')
#df_IMAGE
df_ARTICLE_IMAGE = pd.DataFrame(ARTICLE_IMAGE)
#df_ARTICLE_IMAGE

df_VIDEO = pd.DataFrame(VIDEO)
df_VIDEO['Decription'] = df_VIDEO['Decription'].replace('', 'No Description')
#df_VIDEO
df_ARTICLE_VIDEO = pd.DataFrame(ARTICLE_VIDEO)
#df_ARTICLE_VIDEO



# df_ARTICLE.to_csv(r'C:\Users\Admin\Downloads\ARTICLE.csv',
#          index=False, encoding='utf-8-sig')
# df_IMAGE.to_csv(r'C:\Users\Admin\Downloads\IMAGE.csv',
#          index=False, encoding='utf-8-sig')
# df_ARTICLE_IMAGE.to_csv(r'C:\Users\Admin\Downloads\ARTICLE_IMAGE.csv',
#          index=False, encoding='utf-8-sig')
# df_VIDEO.to_csv(r'C:\Users\Admin\Downloads\VIDEO.csv',
#          index=False, encoding='utf-8-sig')
# df_ARTICLE_VIDEO.to_csv(r'C:\Users\Admin\Downloads\ARTICLE_VIDEO.csv',
#          index=False, encoding='utf-8-sig')

file_path = r'C:\Users\Admin\Downloads\ArticleDataset.xlsx'
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    df_ARTICLE.to_excel(writer, sheet_name='ARTICLE', index=False)
    df_IMAGE.to_excel(writer, sheet_name='IMAGE', index=False)
    df_ARTICLE_IMAGE.to_excel(writer, sheet_name='ARTICLE_IMAGE', index=False)
    df_VIDEO.to_excel(writer, sheet_name='VIDEO', index=False)
    df_ARTICLE_VIDEO.to_excel(writer, sheet_name='ARTICLE_VIDEO', index=False)
    
    
    
print(f'Data saved to {file_path}')
# Out:
# Data saved to C:\Users\Admin\Downloads\ArticleDataset.xlsx

# %%
df_ARTICLE
# Out:
#                    ArticleID  \
# 0    h370-185250318124157703
# 1    aine-185250318112647991
# 2    guoi-185250318102836036
# 3    loan-185250318103542377
# 4    gaza-185250318100820037
# ..                       ...
# 281  -dao-185250317170500719
# 282  tien-185250313230514292
# 283  ao-bi-18525031512210285
# 284  -ram-185250317071417069
# 285  -nam-185250317124927224
#
#                                                  Title  \
# 0       Nhà khoa học tuyên bố tìm ra xác máy bay MH370
# 1    Trung Quốc sẵn sàng tham gia tái thiết Ukraine...
# 2    Chính quyền ông Trump tranh cãi với thẩm phán ...
# 3    Trung Quốc triển khai gần 60 máy bay sau phát ...
# 4    Israel tham vấn Mỹ trước khi tấn công, ít nhất...
# ..                                                 ...
# 281  Ông chủ Samsung ra mệnh lệnh thép cho giới lãn...
# 282  Mỹ phạt sàn OKX nửa tỉ USD tội vi phạm luật ch...
# 283  Thúc đẩy đổi mới sáng tạo trong ngành chế biến...
# ...
